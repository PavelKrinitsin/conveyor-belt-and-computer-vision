# %% [markdown]
# # Создание датасета

# %% [markdown]
# Импорт необходимых библиотек

# %%
import os
import glob
import imageio
import shutil
import xml.etree.ElementTree as ET
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import random

# %% [markdown]
# Загрузка изображений и их аннотаций

# %%
img_path = '/content/images'
annotations = '/content/annotation'

# %%
# Загружаем изображения как массивы NumPy и добавляем их в список images
images = []
for file in glob.glob(os.path.join(img_path, '*.jpg')):
    images.append(imageio.imread(file))
# Out:
# <ipython-input-12-2ce9de1eb72a>:4: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   images.append(imageio.imread(file))

# %%
# Сколько у нас изображений
print('We have {} images'.format(len(images)))
# Out:
# We have 210 images

# %%
# Размеры изображений
for index, file in enumerate(glob.glob(os.path.join(img_path, '*.jpg'))):
    print('Image {} has size of {}'.format(os.path.basename(file), images[index].shape))
# Out:
# Image 3 (10).jpg has size of (480, 854, 3)
# Image 2 (125).jpg has size of (480, 854, 3)
# Image 2 (31).jpg has size of (480, 854, 3)
# Image 3 (77).jpg has size of (480, 854, 3)
# Image 2 (40).jpg has size of (480, 854, 3)
# Image 2 (27).jpg has size of (480, 854, 3)
# Image 2 (114).jpg has size of (480, 854, 3)
# Image 1 (1583).jpg has size of (480, 854, 3)
# Image 1 (3044).jpg has size of (480, 854, 3)
# Image 3 (100).jpg has size of (480, 854, 3)
# Image 3 (56).jpg has size of (480, 854, 3)
# Image 2 (136).jpg has size of (480, 854, 3)
# Image 1 (2).jpg has size of (480, 854, 3)
# Image 1.1 (1029).jpg has size of (480, 854, 3)
# Image 1 (2719).jpg has size of (480, 854, 3)
# Image 1 (1226).jpg has size of (480, 854, 3)
# Image 2 (129).jpg has size of (480, 854, 3)
# Image 1 (108).jpg has size of (480, 854, 3)
# Image 1 (3).jpg has size of (480, 854, 3)
# Image 1 (805).jpg has size of (480, 854, 3)
# Image 1.1 (2086).jpg has size of (480, 854, 3)
# Image 2 (123).jpg has size of (480, 854, 3)
# Image 3 (41).jpg has size of (480, 854, 3)
# Image 1.1 (2900).jpg has size of (480, 854, 3)
# Image 1 (1447).jpg has size of (480, 854, 3)
# Image 3 (143).jpg has size of (480, 854, 3)
# Image 2 (85).jpg has size of (480, 854, 3)
# Image 2 (109).jpg has size of (480, 854, 3)
# Image 2 (71).jpg has size of (480, 854, 3)
# Image 3 (70).jpg has size of (480, 854, 3)
# Image 1.1 (2975).jpg has size of (480, 854, 3)
# Image 2 (145).jpg has size of (480, 854, 3)
# Image 3 (61).jpg has size of (480, 854, 3)
# Image 2 (134).jpg has size of (480, 854, 3)
# Image 1 (506).jpg has size of (480, 854, 3)
# Image 2 (61).jpg has size of (480, 854, 3)
# Image 3 (67).jpg has size of (480, 854, 3)
# Image 2 (147).jpg has size of (480, 854, 3)
# Image 3 (86).jpg has size of (480, 854, 3)
# Image 3 (111).jpg has size of (480, 854, 3)
# Image 3 (136).jpg has size of (480, 854, 3)
# Image 2 (6).jpg has size of (480, 854, 3)
# Image 2 (46).jpg has size of (480, 854, 3)
# Image 1 (1906).jpg has size of (480, 854, 3)
# Image 1.1 (407).jpg has size of (480, 854, 3)
# Image 1 (2158).jpg has size of (480, 854, 3)
# Image 2 (131).jpg has size of (480, 854, 3)
# Image 3 (98).jpg has size of (480, 854, 3)
# Image 3 (121).jpg has size of (480, 854, 3)
# Image 2 (101).jpg has size of (480, 854, 3)
# Image 1 (1438).jpg has size of (480, 854, 3)
# Image 3 (129).jpg has size of (480, 854, 3)
# Image 1 (366).jpg has size of (480, 854, 3)
# Image 1.1 (1045).jpg has size of (480, 854, 3)
# Image 2 (88).jpg has size of (480, 854, 3)
# Image 3 (71).jpg has size of (480, 854, 3)
# Image 3 (113).jpg has size of (480, 854, 3)
# Image 1.1 (655).jpg has size of (480, 854, 3)
# Image 2 (13).jpg has size of (480, 854, 3)
# Image 3 (135).jpg has size of (480, 854, 3)
# Image 3 (115).jpg has size of (480, 854, 3)
# Image 3 (53).jpg has size of (480, 854, 3)
# Image 1 (1934).jpg has size of (480, 854, 3)
# Image 1.1 (673).jpg has size of (480, 854, 3)
# Image 3 (109).jpg has size of (480, 854, 3)
# Image 2 (77).jpg has size of (480, 854, 3)
# Image 3 (80).jpg has size of (480, 854, 3)
# Image 2 (63).jpg has size of (480, 854, 3)
# Image 3 (123).jpg has size of (480, 854, 3)
# Image 3 (96).jpg has size of (480, 854, 3)
# Image 1.1 (2948).jpg has size of (480, 854, 3)
# Image 2 (60).jpg has size of (480, 854, 3)
# Image 2 (70).jpg has size of (480, 854, 3)
# Image 1.1 (1440).jpg has size of (480, 854, 3)
# Image 2 (72).jpg has size of (480, 854, 3)
# Image 1 (525).jpg has size of (480, 854, 3)
# Image 1 (4).jpg has size of (480, 854, 3)
# Image 1.1 (2946).jpg has size of (480, 854, 3)
# Image 1 (3071).jpg has size of (480, 854, 3)
# Image 1 (1).jpg has size of (480, 854, 3)
# Image 2 (56).jpg has size of (480, 854, 3)
# Image 1.1 (2716).jpg has size of (480, 854, 3)
# Image 1.1 (2942).jpg has size of (480, 854, 3)
# Image 3 (151).jpg has size of (480, 854, 3)
# Image 1.1 (1430).jpg has size of (480, 854, 3)
# Image 1 (2692).jpg has size of (480, 854, 3)
# Image 1 (1104).jpg has size of (480, 854, 3)
# Image 2 (143).jpg has size of (480, 854, 3)
# Image 3 (133).jpg has size of (480, 854, 3)
# Image 3 (73).jpg has size of (480, 854, 3)
# Image 1 (1555).jpg has size of (480, 854, 3)
# Image 2 (95).jpg has size of (480, 854, 3)
# Image 3 (105).jpg has size of (480, 854, 3)
# Image 1.1 (2939).jpg has size of (480, 854, 3)
# Image 1 (5).jpg has size of (480, 854, 3)
# Image 3 (48).jpg has size of (480, 854, 3)
# Image 2 (65).jpg has size of (480, 854, 3)
# Image 3 (118).jpg has size of (480, 854, 3)
# Image 3 (137).jpg has size of (480, 854, 3)
# Image 3 (138).jpg has size of (480, 854, 3)
# Image 1 (951).jpg has size of (480, 854, 3)
# Image 2 (119).jpg has size of (480, 854, 3)
# Image 3 (146).jpg has size of (480, 854, 3)
# Image 2 (50).jpg has size of (480, 854, 3)
# Image 2 (36).jpg has size of (480, 854, 3)
# Image 1 (924).jpg has size of (480, 854, 3)
# Image 1 (954).jpg has size of (480, 854, 3)
# Image 3 (21).jpg has size of (480, 854, 3)
# Image 2 (120).jpg has size of (480, 854, 3)
# Image 2 (68).jpg has size of (480, 854, 3)
# Image 1 (1252).jpg has size of (480, 854, 3)
# Image 2 (111).jpg has size of (480, 854, 3)
# Image 3 (54).jpg has size of (480, 854, 3)
# Image 2 (112).jpg has size of (480, 854, 3)
# Image 1 (1693).jpg has size of (480, 854, 3)
# Image 2 (108).jpg has size of (480, 854, 3)
# Image 3 (142).jpg has size of (480, 854, 3)
# Image 2 (106).jpg has size of (480, 854, 3)
# Image 2 (121).jpg has size of (480, 854, 3)
# Image 3 (103).jpg has size of (480, 854, 3)
# Image 2 (87).jpg has size of (480, 854, 3)
# Image 3 (102).jpg has size of (480, 854, 3)
# Image 1 (1394).jpg has size of (480, 854, 3)
# Image 3 (6).jpg has size of (480, 854, 3)
# Image 1 (680).jpg has size of (480, 854, 3)
# Image 3 (3).jpg has size of (480, 854, 3)
# Image 1 (906).jpg has size of (480, 854, 3)
# Image 1 (1086).jpg has size of (480, 854, 3)
# Image 3 (124).jpg has size of (480, 854, 3)
# Image 1 (1050).jpg has size of (480, 854, 3)
# Image 1 (650).jpg has size of (480, 854, 3)
# Image 3 (92).jpg has size of (480, 854, 3)
# Image 3 (119).jpg has size of (480, 854, 3)
# Image 2 (128).jpg has size of (480, 854, 3)
# Image 1 (786).jpg has size of (480, 854, 3)
# Image 3 (89).jpg has size of (480, 854, 3)
# Image 3 (33).jpg has size of (480, 854, 3)
# Image 3 (107).jpg has size of (480, 854, 3)
# Image 3 (150).jpg has size of (480, 854, 3)
# Image 3 (122).jpg has size of (480, 854, 3)
# Image 1 (1237).jpg has size of (480, 854, 3)
# Image 3 (149).jpg has size of (480, 854, 3)
# Image 3 (110).jpg has size of (480, 854, 3)
# Image 3 (152).jpg has size of (480, 854, 3)
# Image 2 (1).jpg has size of (480, 854, 3)
# Image 2 (103).jpg has size of (480, 854, 3)
# Image 2 (69).jpg has size of (480, 854, 3)
# Image 1 (1403).jpg has size of (480, 854, 3)
# Image 1 (1703).jpg has size of (480, 854, 3)
# Image 2 (142).jpg has size of (480, 854, 3)
# Image 2 (80).jpg has size of (480, 854, 3)
# Image 3 (99).jpg has size of (480, 854, 3)
# Image 3 (117).jpg has size of (480, 854, 3)
# Image 1 (237).jpg has size of (480, 854, 3)
# Image 1 (536).jpg has size of (480, 854, 3)
# Image 3 (95).jpg has size of (480, 854, 3)
# Image 3 (45).jpg has size of (480, 854, 3)
# Image 3 (79).jpg has size of (480, 854, 3)
# Image 2 (110).jpg has size of (480, 854, 3)
# Image 2 (75).jpg has size of (480, 854, 3)
# Image 1 (1068).jpg has size of (480, 854, 3)
# Image 1 (824).jpg has size of (480, 854, 3)
# Image 2 (74).jpg has size of (480, 854, 3)
# Image 3 (81).jpg has size of (480, 854, 3)
# Image 3 (134).jpg has size of (480, 854, 3)
# Image 2 (89).jpg has size of (480, 854, 3)
# Image 1.1 (381).jpg has size of (480, 854, 3)
# Image 2 (102).jpg has size of (480, 854, 3)
# Image 3 (127).jpg has size of (480, 854, 3)
# Image 2 (97).jpg has size of (480, 854, 3)
# Image 1 (1263).jpg has size of (480, 854, 3)
# Image 1.1 (429).jpg has size of (480, 854, 3)
# Image 2 (20).jpg has size of (480, 854, 3)
# Image 2 (82).jpg has size of (480, 854, 3)
# Image 2 (3).jpg has size of (480, 854, 3)
# Image 3 (72).jpg has size of (480, 854, 3)
# Image 3 (145).jpg has size of (480, 854, 3)
# Image 3 (88).jpg has size of (480, 854, 3)
# Image 1 (1573).jpg has size of (480, 854, 3)
# Image 3 (7).jpg has size of (480, 854, 3)
# Image 2 (137).jpg has size of (480, 854, 3)
# Image 2 (127).jpg has size of (480, 854, 3)
# Image 3 (144).jpg has size of (480, 854, 3)
# Image 1.1 (2751).jpg has size of (480, 854, 3)
# Image 1 (2130).jpg has size of (480, 854, 3)
# Image 2 (99).jpg has size of (480, 854, 3)
# Image 2 (10).jpg has size of (480, 854, 3)
# Image 3 (116).jpg has size of (480, 854, 3)
# Image 2 (78).jpg has size of (480, 854, 3)
# Image 2 (33).jpg has size of (480, 854, 3)
# Image 2 (83).jpg has size of (480, 854, 3)
# Image 2 (86).jpg has size of (480, 854, 3)
# Image 1 (3093).jpg has size of (480, 854, 3)
# Image 1 (1674).jpg has size of (480, 854, 3)
# Image 2 (79).jpg has size of (480, 854, 3)
# Image 2 (117).jpg has size of (480, 854, 3)
# Image 1 (1546).jpg has size of (480, 854, 3)
# Image 1 (661).jpg has size of (480, 854, 3)
# Image 2 (105).jpg has size of (480, 854, 3)
# Image 3 (106).jpg has size of (480, 854, 3)
# Image 3 (84).jpg has size of (480, 854, 3)
# Image 2 (76).jpg has size of (480, 854, 3)
# Image 3 (126).jpg has size of (480, 854, 3)
# Image 2 (141).jpg has size of (480, 854, 3)
# Image 2 (17).jpg has size of (480, 854, 3)
# Image 1 (81).jpg has size of (480, 854, 3)
# Image 3 (46).jpg has size of (480, 854, 3)
# Image 3 (5).jpg has size of (480, 854, 3)
# Image 1.1 (2944).jpg has size of (480, 854, 3)
# Image 1.1 (2987).jpg has size of (480, 854, 3)

# %% [markdown]
# Проверяем загруженнные файлы

# %%
# Имена XML файлов соответствуют именам файлов изображений
for file in glob.glob(os.path.join(annotations, '*.xml')):
    print(file)
# Out:
# /content/annotation/2 (112).xml
# /content/annotation/3 (86).xml
# /content/annotation/2 (76).xml
# /content/annotation/1 (1438).xml
# /content/annotation/1 (1703).xml
# /content/annotation/2 (80).xml
# /content/annotation/2 (110).xml
# /content/annotation/2 (117).xml
# /content/annotation/1 (1252).xml
# /content/annotation/1.1 (407).xml
# /content/annotation/2 (78).xml
# /content/annotation/2 (69).xml
# /content/annotation/3 (100).xml
# /content/annotation/1 (4).xml
# /content/annotation/2 (60).xml
# /content/annotation/3 (110).xml
# /content/annotation/2 (106).xml
# /content/annotation/1 (1226).xml
# /content/annotation/2 (134).xml
# /content/annotation/3 (70).xml
# /content/annotation/1 (650).xml
# /content/annotation/2 (141).xml
# /content/annotation/3 (137).xml
# /content/annotation/1 (906).xml
# /content/annotation/2 (86).xml
# /content/annotation/2 (77).xml
# /content/annotation/1.1 (2948).xml
# /content/annotation/3 (56).xml
# /content/annotation/2 (97).xml
# /content/annotation/2 (75).xml
# /content/annotation/3 (121).xml
# /content/annotation/1.1 (2939).xml
# /content/annotation/1 (1263).xml
# /content/annotation/1 (506).xml
# /content/annotation/3 (116).xml
# /content/annotation/3 (115).xml
# /content/annotation/3 (46).xml
# /content/annotation/3 (109).xml
# /content/annotation/1 (2158).xml
# /content/annotation/2 (40).xml
# /content/annotation/1 (951).xml
# /content/annotation/2 (137).xml
# /content/annotation/3 (71).xml
# /content/annotation/1 (536).xml
# /content/annotation/3 (67).xml
# /content/annotation/2 (129).xml
# /content/annotation/1 (237).xml
# /content/annotation/2 (136).xml
# /content/annotation/1.1 (2900).xml
# /content/annotation/2 (85).xml
# /content/annotation/2 (1).xml
# /content/annotation/2 (74).xml
# /content/annotation/2 (128).xml
# /content/annotation/2 (50).xml
# /content/annotation/2 (131).xml
# /content/annotation/3 (113).xml
# /content/annotation/3 (33).xml
# /content/annotation/2 (79).xml
# /content/annotation/3 (77).xml
# /content/annotation/1 (1).xml
# /content/annotation/3 (41).xml
# /content/annotation/3 (54).xml
# /content/annotation/1 (1693).xml
# /content/annotation/1 (1674).xml
# /content/annotation/3 (96).xml
# /content/annotation/1 (1573).xml
# /content/annotation/2 (143).xml
# /content/annotation/2 (145).xml
# /content/annotation/1.1 (2946).xml
# /content/annotation/1 (924).xml
# /content/annotation/1 (1104).xml
# /content/annotation/2 (20).xml
# /content/annotation/1 (1050).xml
# /content/annotation/1.1 (1045).xml
# /content/annotation/2 (61).xml
# /content/annotation/1.1 (429).xml
# /content/annotation/2 (6).xml
# /content/annotation/3 (5).xml
# /content/annotation/3 (136).xml
# /content/annotation/2 (103).xml
# /content/annotation/1 (1906).xml
# /content/annotation/1 (81).xml
# /content/annotation/2 (71).xml
# /content/annotation/2 (95).xml
# /content/annotation/3 (111).xml
# /content/annotation/2 (10).xml
# /content/annotation/3 (88).xml
# /content/annotation/1 (1555).xml
# /content/annotation/1 (366).xml
# /content/annotation/2 (111).xml
# /content/annotation/3 (143).xml
# /content/annotation/1.1 (1029).xml
# /content/annotation/1 (1934).xml
# /content/annotation/2 (31).xml
# /content/annotation/1 (2692).xml
# /content/annotation/3 (145).xml
# /content/annotation/3 (118).xml
# /content/annotation/3 (72).xml
# /content/annotation/2 (142).xml
# /content/annotation/1 (1583).xml
# /content/annotation/3 (129).xml
# /content/annotation/1 (3).xml
# /content/annotation/1 (1086).xml
# /content/annotation/3 (107).xml
# /content/annotation/3 (105).xml
# /content/annotation/1 (954).xml
# /content/annotation/3 (149).xml
# /content/annotation/3 (79).xml
# /content/annotation/1 (3044).xml
# /content/annotation/1 (108).xml
# /content/annotation/2 (3).xml
# /content/annotation/1 (824).xml
# /content/annotation/3 (144).xml
# /content/annotation/1 (1394).xml
# /content/annotation/1 (3093).xml
# /content/annotation/2 (99).xml
# /content/annotation/3 (122).xml
# /content/annotation/1 (680).xml
# /content/annotation/3 (3).xml
# /content/annotation/2 (121).xml
# /content/annotation/3 (103).xml
# /content/annotation/2 (120).xml
# /content/annotation/3 (133).xml
# /content/annotation/1.1 (2975).xml
# /content/annotation/2 (63).xml
# /content/annotation/2 (105).xml
# /content/annotation/3 (21).xml
# /content/annotation/2 (102).xml
# /content/annotation/3 (6).xml
# /content/annotation/1 (1403).xml
# /content/annotation/2 (123).xml
# /content/annotation/3 (92).xml
# /content/annotation/3 (89).xml
# /content/annotation/1 (2130).xml
# /content/annotation/1 (1237).xml
# /content/annotation/2 (127).xml
# /content/annotation/1.1 (2987).xml
# /content/annotation/1.1 (2942).xml
# /content/annotation/1.1 (2716).xml
# /content/annotation/3 (73).xml
# /content/annotation/3 (80).xml
# /content/annotation/1 (2).xml
# /content/annotation/1.1 (381).xml
# /content/annotation/3 (98).xml
# /content/annotation/3 (117).xml
# /content/annotation/1 (1068).xml
# /content/annotation/3 (61).xml
# /content/annotation/2 (109).xml
# /content/annotation/2 (83).xml
# /content/annotation/2 (65).xml
# /content/annotation/3 (146).xml
# /content/annotation/3 (150).xml
# /content/annotation/1 (3071).xml
# /content/annotation/2 (89).xml
# /content/annotation/3 (134).xml
# /content/annotation/1 (2719).xml
# /content/annotation/2 (87).xml
# /content/annotation/2 (147).xml
# /content/annotation/1 (1546).xml
# /content/annotation/3 (102).xml
# /content/annotation/1 (525).xml
# /content/annotation/3 (84).xml
# /content/annotation/1 (805).xml
# /content/annotation/2 (101).xml
# /content/annotation/2 (56).xml
# /content/annotation/2 (46).xml
# /content/annotation/3 (152).xml
# /content/annotation/1 (1447).xml
# /content/annotation/2 (36).xml
# /content/annotation/1.1 (2944).xml
# /content/annotation/3 (10).xml
# /content/annotation/3 (126).xml
# /content/annotation/3 (151).xml
# /content/annotation/2 (125).xml
# /content/annotation/2 (17).xml
# /content/annotation/3 (135).xml
# /content/annotation/3 (99).xml
# /content/annotation/2 (70).xml
# /content/annotation/3 (123).xml
# /content/annotation/1 (661).xml
# /content/annotation/1 (786).xml
# /content/annotation/3 (142).xml
# /content/annotation/3 (119).xml
# /content/annotation/3 (48).xml
# /content/annotation/1.1 (655).xml
# /content/annotation/1.1 (1440).xml
# /content/annotation/1.1 (2086).xml
# /content/annotation/1.1 (2751).xml
# /content/annotation/2 (119).xml
# /content/annotation/2 (72).xml
# /content/annotation/2 (13).xml
# /content/annotation/3 (95).xml
# /content/annotation/2 (82).xml
# /content/annotation/1 (5).xml
# /content/annotation/1.1 (1430).xml
# /content/annotation/3 (7).xml
# /content/annotation/2 (108).xml
# /content/annotation/2 (88).xml
# /content/annotation/2 (33).xml
# /content/annotation/3 (81).xml
# /content/annotation/3 (45).xml
# /content/annotation/3 (53).xml
# /content/annotation/3 (106).xml
# /content/annotation/2 (27).xml
# /content/annotation/2 (68).xml
# /content/annotation/1.1 (673).xml
# /content/annotation/3 (124).xml
# /content/annotation/3 (138).xml
# /content/annotation/3 (127).xml
# /content/annotation/2 (114).xml

# %%
# Проверяем XML файлы
for xml_file in glob.glob(os.path.join(annotations, '*.xml')):
    with open(xml_file, "r") as annotation_text:
        print(annotation_text.read())
# Out:
# <annotation>
#   <filename>2 (112).jpg</filename>
#   <folder></folder>
#   <source>
#     <sourceImage></sourceImage>
#     <sourceAnnotation>Datumaro</sourceAnnotation>
#   </source>
#   <imagesize>
#     <nrows>480</nrows>
#     <ncols>854</ncols>
#   </imagesize>
#   <object>
#     <name>break</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>0</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>537.08</x>
#         <y>233.02</y>
#       </pt>
#       <pt>
#         <x>516.66</x>
#         <y>224.42</y>
#       </pt>
#       <pt>
#         <x>505.52</x>
#         <y>194.32</y>
#       </pt>
#       <pt>
#         <x>531.71</x>
#         <y>177.12</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes></attributes>
#   </object>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>1</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>128.21</x>
#         <y>146.72</y>
#       </pt>
#       <pt>
#         <x>512.65</x>
#         <y>39.05</y>
#       </pt>
#       <pt>
#         <x>530.00</x>
#         <y>172.75</y>
#       </pt>
#       <pt>
#         <x>502.55</x>
#         <y>192.15</y>
#       </pt>
#       <pt>
#         <x>514.25</x>
#         <y>225.45</y>
#       </pt>
#       <pt>
#         <x>535.25</x>
#         <y>236.50</y>
#       </pt>
#       <pt>
#         <x>543.90</x>
#         <y>321.80</y>
#       </pt>
#       <pt>
#         <x>548.75</x>
#         <y>383.15</y>
#       </pt>
#       <pt>
#         <x>126.72</x>
#         <y>456.60</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=0, keyframe=False</attributes>
#   </object>
#   <object>
#     <name>joint</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>2</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>507.45</x>
#         <y>1.20</y>
#       </pt>
#       <pt>
#         <x>628.05</x>
#         <y>2.20</y>
#       </pt>
#       <pt>
#         <x>650.10</x>
#         <y>96.05</y>
#       </pt>
#       <pt>
#         <x>708.30</x>
#         <y>354.05</y>
#       </pt>
#       <pt>
#         <x>722.75</x>
#         <y>479.70</y>
#       </pt>
#       <pt>
#         <x>575.75</x>
#         <y>479.65</y>
#       </pt>
#       <pt>
#         <x>552.05</x>
#         <y>479.45</y>
#       </pt>
#       <pt>
#         <x>555.30</x>
#         <y>479.80</y>
#       </pt>
#       <pt>
#         <x>555.90</x>
#         <y>424.25</y>
#       </pt>
#       <pt>
#         <x>547.45</x>
#         <y>317.00</y>
#       </pt>
#       <pt>
#         <x>533.00</x>
#         <y>161.75</y>
#       </pt>
#       <pt>
#         <x>517.90</x>
#         <y>59.40</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=1, keyframe=False</attributes>
#   </object>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>3</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>647.60</x>
#         <y>69.80</y>
#       </pt>
#       <pt>
#         <x>632.60</x>
#         <y>2.80</y>
#       </pt>
#       <pt>
#         <x>724.50</x>
#         <y>2.80</y>
#       </pt>
#       <pt>
#         <x>725.70</x>
#         <y>346.10</y>
#       </pt>
#       <pt>
#         <x>711.90</x>
#         <y>352.80</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=3, keyframe=True</attributes>
#   </object>
# </annotation>
#
# <annotation>
#   <filename>3 (86).jpg</filename>
#   <folder></folder>
#   <source>
#     <sourceImage></sourceImage>
#     <sourceAnnotation>Datumaro</sourceAnnotation>
#   </source>
#   <imagesize>
#     <nrows>480</nrows>
#     <ncols>854</ncols>
#   </imagesize>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>0</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>267.44</x>
#         <y>131.58</y>
#       </pt>
#       <pt>
#         <x>585.58</x>
#         <y>34.29</y>
#       </pt>
#       <pt>
#         <x>588.16</x>
#         <y>233.18</y>
#       </pt>
#       <pt>
#         <x>269.60</x>
#         <y>284.40</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=4, keyframe=False</attributes>
#   </object>
#   <object>
#     <name>break</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>1</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>399.10</x>
#         <y>422.50</y>
#       </pt>
#       <pt>
#         <x>417.40</x>
#         <y>387.60</y>
#       </pt>
#       <pt>
#         <x>505.90</x>
#         <y>383.90</y>
#       </pt>
#       <pt>
#         <x>513.50</x>
#         <y>422.20</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=6, keyframe=True</attributes>
#   </object>
# </annotation>
#
# <annotation>
#   <filename>2 (76).jpg</filename>
#   <folder></folder>
#   <source>
#     <sourceImage></sourceImage>
#     <sourceAnnotation>Datumaro</sourceAnnotation>
#   </source>
#   <imagesize>
#     <nrows>480</nrows>
#     <ncols>854</ncols>
#   </imagesize>
#   <object>
#     <name>break</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>0</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>358.75</x>
#         <y>215.61</y>
#       </pt>
#       <pt>
#         <x>338.11</x>
#         <y>227.48</y>
#       </pt>
#       <pt>
#         <x>337.07</x>
#         <y>247.60</y>
#       </pt>
#       <pt>
#         <x>353.59</x>
#         <y>267.73</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes></attributes>
#   </object>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>1</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>128.62</x>
#         <y>143.89</y>
#       </pt>
#       <pt>
#         <x>352.04</x>
#         <y>78.88</y>
#       </pt>
#       <pt>
#         <x>361.33</x>
#         <y>164.02</y>
#       </pt>
#       <pt>
#         <x>358.75</x>
#         <y>214.06</y>
#       </pt>
#       <pt>
#         <x>336.56</x>
#         <y>222.84</y>
#       </pt>
#       <pt>
#         <x>331.91</x>
#         <y>249.15</y>
#       </pt>
#       <pt>
#         <x>352.55</x>
#         <y>269.27</y>
#       </pt>
#       <pt>
#         <x>342.75</x>
#         <y>356.47</y>
#       </pt>
#       <pt>
#         <x>325.72</x>
#         <y>418.39</y>
#       </pt>
#       <pt>
#         <x>127.07</x>
#         <y>457.09</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes></attributes>
#   </object>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>2</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>481.10</x>
#         <y>278.60</y>
#       </pt>
#       <pt>
#         <x>462.40</x>
#         <y>50.10</y>
#       </pt>
#       <pt>
#         <x>610.50</x>
#         <y>2.50</y>
#       </pt>
#       <pt>
#         <x>683.60</x>
#         <y>1.60</y>
#       </pt>
#       <pt>
#         <x>725.60</x>
#         <y>2.40</y>
#       </pt>
#       <pt>
#         <x>726.70</x>
#         <y>110.00</y>
#       </pt>
#       <pt>
#         <x>722.00</x>
#         <y>190.20</y>
#       </pt>
#       <pt>
#         <x>724.40</x>
#         <y>340.30</y>
#       </pt>
#       <pt>
#         <x>478.30</x>
#         <y>378.90</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=0, keyframe=True</attributes>
#   </object>
#   <object>
#     <name>joint</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>3</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>348.20</x>
#         <y>373.30</y>
#       </pt>
#       <pt>
#         <x>366.10</x>
#         <y>154.00</y>
#       </pt>
#       <pt>
#         <x>360.40</x>
#         <y>79.80</y>
#       </pt>
#       <pt>
#         <x>351.90</x>
#         <y>33.60</y>
#       </pt>
#       <pt>
#         <x>342.00</x>
#         <y>0.00</y>
#       </pt>
#       <pt>
#         <x>382.00</x>
#         <y>1.00</y>
#       </pt>
#       <pt>
#         <x>454.40</x>
#         <y>1.90</y>
#       </pt>
#       <pt>
#         <x>471.80</x>
#         <y>167.10</y>
#       </pt>
#       <pt>
#         <x>475.20</x>
#         <y>350.40</y>
#       </pt>
#       <pt>
#         <x>460.90</x>
#         <y>480.00</y>
#       </pt>
#       <pt>
#         <x>321.90</x>
#         <y>479.70</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=1, keyframe=True</attributes>
#   </object>
# </annotation>
#
# <annotation>
#   <filename>1 (1438).jpg</filename>
#   <folder></folder>
#   <source>
#     <sourceImage></sourceImage>
#     <sourceAnnotation>Datumaro</sourceAnnotation>
#   </source>
#   <imagesize>
#     <nrows>480</nrows>
#     <ncols>854</ncols>
#   </imagesize>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>0</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>127.55</x>
#         <y>152.35</y>
#       </pt>
#       <pt>
#         <x>641.30</x>
#         <y>1.40</y>
#       </pt>
#       <pt>
#         <x>726.35</x>
#         <y>2.90</y>
#       </pt>
#       <pt>
#         <x>725.65</x>
#         <y>341.75</y>
#       </pt>
#       <pt>
#         <x>127.65</x>
#         <y>440.25</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=3, keyframe=False</attributes>
#   </object>
# </annotation>
#
# <annotation>
#   <filename>1 (1703).jpg</filename>
#   <folder></folder>
#   <source>
#     <sourceImage></sourceImage>
#     <sourceAnnotation>Datumaro</sourceAnnotation>
#   </source>
#   <imagesize>
#     <nrows>480</nrows>
#     <ncols>854</ncols>
#   </imagesize>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>0</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>126.80</x>
#         <y>156.70</y>
#       </pt>
#       <pt>
#         <x>603.90</x>
#         <y>2.80</y>
#       </pt>
#       <pt>
#         <x>724.10</x>
#         <y>0.20</y>
#       </pt>
#       <pt>
#         <x>726.40</x>
#         <y>344.00</y>
#       </pt>
#       <pt>
#         <x>128.20</x>
#         <y>445.80</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=3, keyframe=True</attributes>
#   </object>
# </annotation>
#
# <annotation>
#   <filename>2 (80).jpg</filename>
#   <folder></folder>
#   <source>
#     <sourceImage></sourceImage>
#     <sourceAnnotation>Datumaro</sourceAnnotation>
#   </source>
#   <imagesize>
#     <nrows>480</nrows>
#     <ncols>854</ncols>
#   </imagesize>
#   <object>
#     <name>break</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>0</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>366.35</x>
#         <y>218.12</y>
#       </pt>
#       <pt>
#         <x>354.55</x>
#         <y>220.27</y>
#       </pt>
#       <pt>
#         <x>350.56</x>
#         <y>233.18</y>
#       </pt>
#       <pt>
#         <x>350.56</x>
#         <y>248.97</y>
#       </pt>
#       <pt>
#         <x>354.87</x>
#         <y>260.09</y>
#       </pt>
#       <pt>
#         <x>365.67</x>
#         <y>278.74</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes></attributes>
#   </object>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>1</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>128.18</x>
#         <y>160.72</y>
#       </pt>
#       <pt>
#         <x>341.95</x>
#         <y>89.69</y>
#       </pt>
#       <pt>
#         <x>334.82</x>
#         <y>415.78</y>
#       </pt>
#       <pt>
#         <x>127.82</x>
#         <y>454.89</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes></attributes>
#   </object>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>2</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>493.70</x>
#         <y>274.60</y>
#       </pt>
#       <pt>
#         <x>479.57</x>
#         <y>46.27</y>
#       </pt>
#       <pt>
#         <x>610.50</x>
#         <y>2.50</y>
#       </pt>
#       <pt>
#         <x>683.60</x>
#         <y>1.60</y>
#       </pt>
#       <pt>
#         <x>725.60</x>
#         <y>2.40</y>
#       </pt>
#       <pt>
#         <x>726.70</x>
#         <y>110.00</y>
#       </pt>
#       <pt>
#         <x>722.00</x>
#         <y>190.20</y>
#       </pt>
#       <pt>
#         <x>724.40</x>
#         <y>340.30</y>
#       </pt>
#       <pt>
#         <x>491.50</x>
#         <y>380.03</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=0, keyframe=False</attributes>
#   </object>
#   <object>
#     <name>joint</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>3</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>366.80</x>
#         <y>294.40</y>
#       </pt>
#       <pt>
#         <x>372.90</x>
#         <y>156.90</y>
#       </pt>
#       <pt>
#         <x>360.40</x>
#         <y>79.80</y>
#       </pt>
#       <pt>
#         <x>351.90</x>
#         <y>33.60</y>
#       </pt>
#       <pt>
#         <x>353.90</x>
#         <y>5.20</y>
#       </pt>
#       <pt>
#         <x>382.00</x>
#         <y>1.00</y>
#       </pt>
#       <pt>
#         <x>464.20</x>
#         <y>2.40</y>
#       </pt>
#       <pt>
#         <x>477.00</x>
#         <y>167.10</y>
#       </pt>
#       <pt>
#         <x>482.90</x>
#         <y>352.50</y>
#       </pt>
#       <pt>
#         <x>469.20</x>
#         <y>478.50</y>
#       </pt>
#       <pt>
#         <x>330.20</x>
#         <y>480.00</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=1, keyframe=True</attributes>
#   </object>
# </annotation>
#
# <annotation>
#   <filename>2 (110).jpg</filename>
#   <folder></folder>
#   <source>
#     <sourceImage></sourceImage>
#     <sourceAnnotation>Datumaro</sourceAnnotation>
#   </source>
#   <imagesize>
#     <nrows>480</nrows>
#     <ncols>854</ncols>
#   </imagesize>
#   <object>
#     <name>break</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>0</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>524.15</x>
#         <y>178.55</y>
#       </pt>
#       <pt>
#         <x>499.46</x>
#         <y>198.26</y>
#       </pt>
#       <pt>
#         <x>508.06</x>
#         <y>222.27</y>
#       </pt>
#       <pt>
#         <x>530.99</x>
#         <y>242.69</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes></attributes>
#   </object>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>1</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>128.21</x>
#         <y>146.72</y>
#       </pt>
#       <pt>
#         <x>502.90</x>
#         <y>41.70</y>
#       </pt>
#       <pt>
#         <x>523.80</x>
#         <y>173.60</y>
#       </pt>
#       <pt>
#         <x>489.20</x>
#         <y>201.50</y>
#       </pt>
#       <pt>
#         <x>510.10</x>
#         <y>229.60</y>
#       </pt>
#       <pt>
#         <x>529.90</x>
#         <y>244.80</y>
#       </pt>
#       <pt>
#         <x>534.80</x>
#         <y>285.50</y>
#       </pt>
#       <pt>
#         <x>541.90</x>
#         <y>384.20</y>
#       </pt>
#       <pt>
#         <x>126.72</x>
#         <y>456.60</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=0, keyframe=True</attributes>
#   </object>
#   <object>
#     <name>joint</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>2</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>501.70</x>
#         <y>0.50</y>
#       </pt>
#       <pt>
#         <x>620.90</x>
#         <y>1.50</y>
#       </pt>
#       <pt>
#         <x>642.20</x>
#         <y>87.10</y>
#       </pt>
#       <pt>
#         <x>695.20</x>
#         <y>354.40</y>
#       </pt>
#       <pt>
#         <x>710.40</x>
#         <y>479.30</y>
#       </pt>
#       <pt>
#         <x>539.70</x>
#         <y>479.30</y>
#       </pt>
#       <pt>
#         <x>546.20</x>
#         <y>480.00</y>
#       </pt>
#       <pt>
#         <x>548.00</x>
#         <y>428.80</y>
#       </pt>
#       <pt>
#         <x>543.30</x>
#         <y>323.00</y>
#       </pt>
#       <pt>
#         <x>527.40</x>
#         <y>163.20</y>
#       </pt>
#       <pt>
#         <x>513.40</x>
#         <y>64.10</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=1, keyframe=True</attributes>
#   </object>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>3</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>642.60</x>
#         <y>69.60</y>
#       </pt>
#       <pt>
#         <x>628.10</x>
#         <y>3.15</y>
#       </pt>
#       <pt>
#         <x>724.50</x>
#         <y>2.80</y>
#       </pt>
#       <pt>
#         <x>725.70</x>
#         <y>346.10</y>
#       </pt>
#       <pt>
#         <x>704.00</x>
#         <y>351.90</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=3, keyframe=False</attributes>
#   </object>
# </annotation>
#
# <annotation>
#   <filename>2 (117).jpg</filename>
#   <folder></folder>
#   <source>
#     <sourceImage></sourceImage>
#     <sourceAnnotation>Datumaro</sourceAnnotation>
#   </source>
#   <imagesize>
#     <nrows>480</nrows>
#     <ncols>854</ncols>
#   </imagesize>
#   <object>
#     <name>break</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>0</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>571.09</x>
#         <y>160.28</y>
#       </pt>
#       <pt>
#         <x>548.51</x>
#         <y>173.53</y>
#       </pt>
#       <pt>
#         <x>547.80</x>
#         <y>191.45</y>
#       </pt>
#       <pt>
#         <x>578.97</x>
#         <y>234.81</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes></attributes>
#   </object>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>1</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>128.21</x>
#         <y>146.72</y>
#       </pt>
#       <pt>
#         <x>546.00</x>
#         <y>32.20</y>
#       </pt>
#       <pt>
#         <x>569.10</x>
#         <y>155.70</y>
#       </pt>
#       <pt>
#         <x>543.80</x>
#         <y>172.40</y>
#       </pt>
#       <pt>
#         <x>543.50</x>
#         <y>196.20</y>
#       </pt>
#       <pt>
#         <x>564.50</x>
#         <y>220.60</y>
#       </pt>
#       <pt>
#         <x>581.60</x>
#         <y>247.50</y>
#       </pt>
#       <pt>
#         <x>595.70</x>
#         <y>368.50</y>
#       </pt>
#       <pt>
#         <x>126.72</x>
#         <y>456.60</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=0, keyframe=True</attributes>
#   </object>
#   <object>
#     <name>joint</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>2</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>543.30</x>
#         <y>2.60</y>
#       </pt>
#       <pt>
#         <x>666.00</x>
#         <y>0.00</y>
#       </pt>
#       <pt>
#         <x>694.50</x>
#         <y>115.70</y>
#       </pt>
#       <pt>
#         <x>727.30</x>
#         <y>245.50</y>
#       </pt>
#       <pt>
#         <x>728.10</x>
#         <y>479.70</y>
#       </pt>
#       <pt>
#         <x>665.50</x>
#         <y>479.30</y>
#       </pt>
#       <pt>
#         <x>613.80</x>
#         <y>477.50</y>
#       </pt>
#       <pt>
#         <x>606.80</x>
#         <y>388.90</y>
#       </pt>
#       <pt>
#         <x>588.10</x>
#         <y>273.80</y>
#       </pt>
#       <pt>
#         <x>570.80</x>
#         <y>131.60</y>
#       </pt>
#       <pt>
#         <x>551.80</x>
#         <y>38.90</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=1, keyframe=True</attributes>
#   </object>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>3</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>698.80</x>
#         <y>53.30</y>
#       </pt>
#       <pt>
#         <x>695.40</x>
#         <y>33.40</y>
#       </pt>
#       <pt>
#         <x>691.17</x>
#         <y>2.53</y>
#       </pt>
#       <pt>
#         <x>724.50</x>
#         <y>2.80</y>
#       </pt>
#       <pt>
#         <x>726.90</x>
#         <y>201.70</y>
#       </pt>
#       <pt>
#         <x>722.30</x>
#         <y>240.60</y>
#       </pt>
#       <pt>
#         <x>705.60</x>
#         <y>99.70</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=3, keyframe=True</attributes>
#   </object>
# </annotation>
#
# <annotation>
#   <filename>1 (1252).jpg</filename>
#   <folder></folder>
#   <source>
#     <sourceImage></sourceImage>
#     <sourceAnnotation>Datumaro</sourceAnnotation>
#   </source>
#   <imagesize>
#     <nrows>480</nrows>
#     <ncols>854</ncols>
#   </imagesize>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>0</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>129.20</x>
#         <y>166.40</y>
#       </pt>
#       <pt>
#         <x>651.60</x>
#         <y>1.10</y>
#       </pt>
#       <pt>
#         <x>726.40</x>
#         <y>0.00</y>
#       </pt>
#       <pt>
#         <x>724.90</x>
#         <y>341.30</y>
#       </pt>
#       <pt>
#         <x>126.10</x>
#         <y>448.10</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=3, keyframe=True</attributes>
#   </object>
# </annotation>
#
# <annotation>
#   <filename>1.1 (407).jpg</filename>
#   <folder></folder>
#   <source>
#     <sourceImage></sourceImage>
#     <sourceAnnotation>Datumaro</sourceAnnotation>
#   </source>
#   <imagesize>
#     <nrows>480</nrows>
#     <ncols>854</ncols>
#   </imagesize>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>0</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>268.08</x>
#         <y>134.05</y>
#       </pt>
#       <pt>
#         <x>478.20</x>
#         <y>76.59</y>
#       </pt>
#       <pt>
#         <x>585.29</x>
#         <y>44.85</y>
#       </pt>
#       <pt>
#         <x>584.27</x>
#         <y>241.40</y>
#       </pt>
#       <pt>
#         <x>268.88</x>
#         <y>287.39</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=3, keyframe=False</attributes>
#   </object>
# </annotation>
#
# <annotation>
#   <filename>2 (78).jpg</filename>
#   <folder></folder>
#   <source>
#     <sourceImage></sourceImage>
#     <sourceAnnotation>Datumaro</sourceAnnotation>
#   </source>
#   <imagesize>
#     <nrows>480</nrows>
#     <ncols>854</ncols>
#   </imagesize>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>0</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>127.07</x>
#         <y>145.44</y>
#       </pt>
#       <pt>
#         <x>358.23</x>
#         <y>78.36</y>
#       </pt>
#       <pt>
#         <x>364.94</x>
#         <y>152.66</y>
#       </pt>
#       <pt>
#         <x>361.84</x>
#         <y>216.64</y>
#       </pt>
#       <pt>
#         <x>336.04</x>
#         <y>222.84</y>
#       </pt>
#       <pt>
#         <x>338.11</x>
#         <y>248.64</y>
#       </pt>
#       <pt>
#         <x>358.23</x>
#         <y>269.27</y>
#       </pt>
#       <pt>
#         <x>352.04</x>
#         <y>336.87</y>
#       </pt>
#       <pt>
#         <x>334.49</x>
#         <y>423.04</y>
#       </pt>
#       <pt>
#         <x>129.13</x>
#         <y>456.06</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes></attributes>
#   </object>
#   <object>
#     <name>break</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>1</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>360.81</x>
#         <y>221.29</y>
#       </pt>
#       <pt>
#         <x>341.72</x>
#         <y>224.90</y>
#       </pt>
#       <pt>
#         <x>341.72</x>
#         <y>243.99</y>
#       </pt>
#       <pt>
#         <x>358.23</x>
#         <y>265.15</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes></attributes>
#   </object>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>2</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>481.10</x>
#         <y>278.60</y>
#       </pt>
#       <pt>
#         <x>472.70</x>
#         <y>48.00</y>
#       </pt>
#       <pt>
#         <x>610.50</x>
#         <y>2.50</y>
#       </pt>
#       <pt>
#         <x>683.60</x>
#         <y>1.60</y>
#       </pt>
#       <pt>
#         <x>725.60</x>
#         <y>2.40</y>
#       </pt>
#       <pt>
#         <x>726.70</x>
#         <y>110.00</y>
#       </pt>
#       <pt>
#         <x>722.00</x>
#         <y>190.20</y>
#       </pt>
#       <pt>
#         <x>724.40</x>
#         <y>340.30</y>
#       </pt>
#       <pt>
#         <x>478.30</x>
#         <y>378.90</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=0, keyframe=True</attributes>
#   </object>
#   <object>
#     <name>joint</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>3</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>357.50</x>
#         <y>373.30</y>
#       </pt>
#       <pt>
#         <x>366.10</x>
#         <y>154.00</y>
#       </pt>
#       <pt>
#         <x>360.40</x>
#         <y>79.80</y>
#       </pt>
#       <pt>
#         <x>351.90</x>
#         <y>33.60</y>
#       </pt>
#       <pt>
#         <x>353.90</x>
#         <y>5.20</y>
#       </pt>
#       <pt>
#         <x>382.00</x>
#         <y>1.00</y>
#       </pt>
#       <pt>
#         <x>464.20</x>
#         <y>2.40</y>
#       </pt>
#       <pt>
#         <x>477.00</x>
#         <y>167.10</y>
#       </pt>
#       <pt>
#         <x>482.90</x>
#         <y>352.50</y>
#       </pt>
#       <pt>
#         <x>469.20</x>
#         <y>478.50</y>
#       </pt>
#       <pt>
#         <x>330.20</x>
#         <y>480.00</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=1, keyframe=True</attributes>
#   </object>
# </annotation>
#
# <annotation>
#   <filename>2 (69).jpg</filename>
#   <folder></folder>
#   <source>
#     <sourceImage></sourceImage>
#     <sourceAnnotation>Datumaro</sourceAnnotation>
#   </source>
#   <imagesize>
#     <nrows>480</nrows>
#     <ncols>854</ncols>
#   </imagesize>
#   <object>
#     <name>break</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>0</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>312.76</x>
#         <y>270.37</y>
#       </pt>
#       <pt>
#         <x>298.57</x>
#         <y>258.37</y>
#       </pt>
#       <pt>
#         <x>294.27</x>
#         <y>236.83</y>
#       </pt>
#       <pt>
#         <x>319.64</x>
#         <y>226.12</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes></attributes>
#   </object>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>1</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>129.16</x>
#         <y>144.81</y>
#       </pt>
#       <pt>
#         <x>319.21</x>
#         <y>91.06</y>
#       </pt>
#       <pt>
#         <x>323.51</x>
#         <y>200.32</y>
#       </pt>
#       <pt>
#         <x>319.21</x>
#         <y>222.64</y>
#       </pt>
#       <pt>
#         <x>290.40</x>
#         <y>233.00</y>
#       </pt>
#       <pt>
#         <x>294.70</x>
#         <y>257.04</y>
#       </pt>
#       <pt>
#         <x>313.62</x>
#         <y>275.57</y>
#       </pt>
#       <pt>
#         <x>304.16</x>
#         <y>331.90</y>
#       </pt>
#       <pt>
#         <x>291.69</x>
#         <y>377.90</y>
#       </pt>
#       <pt>
#         <x>280.94</x>
#         <y>416.13</y>
#       </pt>
#       <pt>
#         <x>128.30</x>
#         <y>454.87</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes></attributes>
#   </object>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>2</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>439.20</x>
#         <y>291.22</y>
#       </pt>
#       <pt>
#         <x>433.40</x>
#         <y>53.70</y>
#       </pt>
#       <pt>
#         <x>610.50</x>
#         <y>2.50</y>
#       </pt>
#       <pt>
#         <x>683.60</x>
#         <y>1.60</y>
#       </pt>
#       <pt>
#         <x>725.60</x>
#         <y>2.40</y>
#       </pt>
#       <pt>
#         <x>726.70</x>
#         <y>110.00</y>
#       </pt>
#       <pt>
#         <x>722.00</x>
#         <y>190.20</y>
#       </pt>
#       <pt>
#         <x>724.40</x>
#         <y>340.30</y>
#       </pt>
#       <pt>
#         <x>434.82</x>
#         <y>384.52</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=0, keyframe=False</attributes>
#   </object>
#   <object>
#     <name>joint</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>3</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>305.00</x>
#         <y>368.80</y>
#       </pt>
#       <pt>
#         <x>333.60</x>
#         <y>159.90</y>
#       </pt>
#       <pt>
#         <x>318.10</x>
#         <y>39.30</y>
#       </pt>
#       <pt>
#         <x>314.80</x>
#         <y>1.30</y>
#       </pt>
#       <pt>
#         <x>342.00</x>
#         <y>0.00</y>
#       </pt>
#       <pt>
#         <x>382.00</x>
#         <y>1.00</y>
#       </pt>
#       <pt>
#         <x>413.57</x>
#         <y>0.13</y>
#       </pt>
#       <pt>
#         <x>420.97</x>
#         <y>43.73</y>
#       </pt>
#       <pt>
#         <x>426.37</x>
#         <y>89.63</y>
#       </pt>
#       <pt>
#         <x>433.10</x>
#         <y>295.80</y>
#       </pt>
#       <pt>
#         <x>401.70</x>
#         <y>479.10</y>
#       </pt>
#       <pt>
#         <x>268.50</x>
#         <y>480.00</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=1, keyframe=False</attributes>
#   </object>
# </annotation>
#
# <annotation>
#   <filename>3 (100).jpg</filename>
#   <folder></folder>
#   <source>
#     <sourceImage></sourceImage>
#     <sourceAnnotation>Datumaro</sourceAnnotation>
#   </source>
#   <imagesize>
#     <nrows>480</nrows>
#     <ncols>854</ncols>
#   </imagesize>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>0</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>267.44</x>
#         <y>131.58</y>
#       </pt>
#       <pt>
#         <x>585.58</x>
#         <y>34.29</y>
#       </pt>
#       <pt>
#         <x>588.16</x>
#         <y>233.18</y>
#       </pt>
#       <pt>
#         <x>269.60</x>
#         <y>284.40</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=4, keyframe=True</attributes>
#   </object>
#   <object>
#     <name>break</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>1</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>444.81</x>
#         <y>410.97</y>
#       </pt>
#       <pt>
#         <x>428.02</x>
#         <y>399.35</y>
#       </pt>
#       <pt>
#         <x>465.90</x>
#         <y>388.15</y>
#       </pt>
#       <pt>
#         <x>483.55</x>
#         <y>379.11</y>
#       </pt>
#       <pt>
#         <x>516.70</x>
#         <y>376.96</y>
#       </pt>
#       <pt>
#         <x>548.12</x>
#         <y>381.70</y>
#       </pt>
#       <pt>
#         <x>558.03</x>
#         <y>395.47</y>
#       </pt>
#       <pt>
#         <x>562.33</x>
#         <y>400.21</y>
#       </pt>
#       <pt>
#         <x>566.21</x>
#         <y>416.14</y>
#       </pt>
#       <pt>
#         <x>450.40</x>
#         <y>422.16</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=5, keyframe=True</attributes>
#   </object>
# </annotation>
#
# <annotation>
#   <filename>1 (4).jpg</filename>
#   <folder></folder>
#   <source>
#     <sourceImage></sourceImage>
#     <sourceAnnotation>Datumaro</sourceAnnotation>
#   </source>
#   <imagesize>
#     <nrows>480</nrows>
#     <ncols>854</ncols>
#   </imagesize>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>0</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>130.10</x>
#         <y>158.20</y>
#       </pt>
#       <pt>
#         <x>600.10</x>
#         <y>5.70</y>
#       </pt>
#       <pt>
#         <x>724.20</x>
#         <y>7.10</y>
#       </pt>
#       <pt>
#         <x>726.00</x>
#         <y>338.80</y>
#       </pt>
#       <pt>
#         <x>132.80</x>
#         <y>434.47</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=3, keyframe=True</attributes>
#   </object>
# </annotation>
#
# <annotation>
#   <filename>2 (60).jpg</filename>
#   <folder></folder>
#   <source>
#     <sourceImage></sourceImage>
#     <sourceAnnotation>Datumaro</sourceAnnotation>
#   </source>
#   <imagesize>
#     <nrows>480</nrows>
#     <ncols>854</ncols>
#   </imagesize>
#   <object>
#     <name>break</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>0</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>265.29</x>
#         <y>287.05</y>
#       </pt>
#       <pt>
#         <x>258.84</x>
#         <y>277.16</y>
#       </pt>
#       <pt>
#         <x>258.84</x>
#         <y>259.10</y>
#       </pt>
#       <pt>
#         <x>277.33</x>
#         <y>241.90</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes></attributes>
#   </object>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>1</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>128.56</x>
#         <y>151.60</y>
#       </pt>
#       <pt>
#         <x>277.33</x>
#         <y>103.45</y>
#       </pt>
#       <pt>
#         <x>285.07</x>
#         <y>183.85</y>
#       </pt>
#       <pt>
#         <x>277.33</x>
#         <y>238.46</y>
#       </pt>
#       <pt>
#         <x>255.83</x>
#         <y>256.09</y>
#       </pt>
#       <pt>
#         <x>256.26</x>
#         <y>277.59</y>
#       </pt>
#       <pt>
#         <x>265.29</x>
#         <y>292.64</y>
#       </pt>
#       <pt>
#         <x>249.43</x>
#         <y>368.75</y>
#       </pt>
#       <pt>
#         <x>226.64</x>
#         <y>432.81</y>
#       </pt>
#       <pt>
#         <x>127.70</x>
#         <y>453.88</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes></attributes>
#   </object>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>2</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>386.40</x>
#         <y>312.70</y>
#       </pt>
#       <pt>
#         <x>388.20</x>
#         <y>69.50</y>
#       </pt>
#       <pt>
#         <x>610.50</x>
#         <y>2.50</y>
#       </pt>
#       <pt>
#         <x>683.60</x>
#         <y>1.60</y>
#       </pt>
#       <pt>
#         <x>725.60</x>
#         <y>2.40</y>
#       </pt>
#       <pt>
#         <x>726.70</x>
#         <y>110.00</y>
#       </pt>
#       <pt>
#         <x>722.00</x>
#         <y>190.20</y>
#       </pt>
#       <pt>
#         <x>724.40</x>
#         <y>340.30</y>
#       </pt>
#       <pt>
#         <x>368.40</x>
#         <y>399.40</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=0, keyframe=True</attributes>
#   </object>
#   <object>
#     <name>joint</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>3</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>257.70</x>
#         <y>364.80</y>
#       </pt>
#       <pt>
#         <x>287.80</x>
#         <y>183.20</y>
#       </pt>
#       <pt>
#         <x>273.90</x>
#         <y>1.50</y>
#       </pt>
#       <pt>
#         <x>282.60</x>
#         <y>0.00</y>
#       </pt>
#       <pt>
#         <x>297.30</x>
#         <y>0.00</y>
#       </pt>
#       <pt>
#         <x>327.40</x>
#         <y>1.90</y>
#       </pt>
#       <pt>
#         <x>371.60</x>
#         <y>0.70</y>
#       </pt>
#       <pt>
#         <x>386.50</x>
#         <y>76.20</y>
#       </pt>
#       <pt>
#         <x>383.80</x>
#         <y>273.10</y>
#       </pt>
#       <pt>
#         <x>343.30</x>
#         <y>480.00</y>
#       </pt>
#       <pt>
#         <x>216.40</x>
#         <y>479.20</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=1, keyframe=True</attributes>
#   </object>
# </annotation>
#
# <annotation>
#   <filename>3 (110).jpg</filename>
#   <folder></folder>
#   <source>
#     <sourceImage></sourceImage>
#     <sourceAnnotation>Datumaro</sourceAnnotation>
#   </source>
#   <imagesize>
#     <nrows>480</nrows>
#     <ncols>854</ncols>
#   </imagesize>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>0</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>267.44</x>
#         <y>131.58</y>
#       </pt>
#       <pt>
#         <x>585.58</x>
#         <y>34.29</y>
#       </pt>
#       <pt>
#         <x>588.16</x>
#         <y>233.18</y>
#       </pt>
#       <pt>
#         <x>269.60</x>
#         <y>284.40</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=4, keyframe=False</attributes>
#   </object>
#   <object>
#     <name>break</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>1</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>528.30</x>
#         <y>402.60</y>
#       </pt>
#       <pt>
#         <x>469.70</x>
#         <y>396.40</y>
#       </pt>
#       <pt>
#         <x>505.30</x>
#         <y>388.20</y>
#       </pt>
#       <pt>
#         <x>483.55</x>
#         <y>379.11</y>
#       </pt>
#       <pt>
#         <x>516.70</x>
#         <y>376.96</y>
#       </pt>
#       <pt>
#         <x>585.10</x>
#         <y>374.50</y>
#       </pt>
#       <pt>
#         <x>585.50</x>
#         <y>388.90</y>
#       </pt>
#       <pt>
#         <x>585.60</x>
#         <y>400.20</y>
#       </pt>
#       <pt>
#         <x>585.80</x>
#         <y>416.60</y>
#       </pt>
#       <pt>
#         <x>536.20</x>
#         <y>418.00</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=5, keyframe=True</attributes>
#   </object>
# </annotation>
#
# <annotation>
#   <filename>2 (106).jpg</filename>
#   <folder></folder>
#   <source>
#     <sourceImage></sourceImage>
#     <sourceAnnotation>Datumaro</sourceAnnotation>
#   </source>
#   <imagesize>
#     <nrows>480</nrows>
#     <ncols>854</ncols>
#   </imagesize>
#   <object>
#     <name>break</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>0</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>489.39</x>
#         <y>242.75</y>
#       </pt>
#       <pt>
#         <x>471.48</x>
#         <y>229.91</y>
#       </pt>
#       <pt>
#         <x>467.00</x>
#         <y>204.23</y>
#       </pt>
#       <pt>
#         <x>486.41</x>
#         <y>178.85</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes></attributes>
#   </object>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>1</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>128.21</x>
#         <y>146.72</y>
#       </pt>
#       <pt>
#         <x>470.00</x>
#         <y>49.60</y>
#       </pt>
#       <pt>
#         <x>481.40</x>
#         <y>175.80</y>
#       </pt>
#       <pt>
#         <x>459.10</x>
#         <y>204.40</y>
#       </pt>
#       <pt>
#         <x>469.30</x>
#         <y>233.20</y>
#       </pt>
#       <pt>
#         <x>491.20</x>
#         <y>246.50</y>
#       </pt>
#       <pt>
#         <x>495.30</x>
#         <y>320.60</y>
#       </pt>
#       <pt>
#         <x>496.80</x>
#         <y>389.20</y>
#       </pt>
#       <pt>
#         <x>126.72</x>
#         <y>456.60</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=0, keyframe=True</attributes>
#   </object>
#   <object>
#     <name>joint</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>2</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>456.50</x>
#         <y>1.25</y>
#       </pt>
#       <pt>
#         <x>580.10</x>
#         <y>0.10</y>
#       </pt>
#       <pt>
#         <x>635.00</x>
#         <y>299.10</y>
#       </pt>
#       <pt>
#         <x>648.70</x>
#         <y>441.80</y>
#       </pt>
#       <pt>
#         <x>651.70</x>
#         <y>479.40</y>
#       </pt>
#       <pt>
#         <x>483.84</x>
#         <y>480.00</y>
#       </pt>
#       <pt>
#         <x>496.10</x>
#         <y>480.00</y>
#       </pt>
#       <pt>
#         <x>498.60</x>
#         <y>352.90</y>
#       </pt>
#       <pt>
#         <x>491.00</x>
#         <y>223.50</y>
#       </pt>
#       <pt>
#         <x>481.50</x>
#         <y>109.50</y>
#       </pt>
#       <pt>
#         <x>462.50</x>
#         <y>6.00</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=1, keyframe=True</attributes>
#   </object>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>3</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>622.43</x>
#         <y>51.83</y>
#       </pt>
#       <pt>
#         <x>618.10</x>
#         <y>38.05</y>
#       </pt>
#       <pt>
#         <x>623.60</x>
#         <y>3.50</y>
#       </pt>
#       <pt>
#         <x>724.50</x>
#         <y>2.80</y>
#       </pt>
#       <pt>
#         <x>725.70</x>
#         <y>346.10</y>
#       </pt>
#       <pt>
#         <x>697.43</x>
#         <y>351.40</y>
#       </pt>
#       <pt>
#         <x>692.50</x>
#         <y>352.22</y>
#       </pt>
#       <pt>
#         <x>677.70</x>
#         <y>354.67</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=3, keyframe=False</attributes>
#   </object>
# </annotation>
#
# <annotation>
#   <filename>1 (1226).jpg</filename>
#   <folder></folder>
#   <source>
#     <sourceImage></sourceImage>
#     <sourceAnnotation>Datumaro</sourceAnnotation>
#   </source>
#   <imagesize>
#     <nrows>480</nrows>
#     <ncols>854</ncols>
#   </imagesize>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>0</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>127.50</x>
#         <y>156.90</y>
#       </pt>
#       <pt>
#         <x>640.30</x>
#         <y>0.00</y>
#       </pt>
#       <pt>
#         <x>726.83</x>
#         <y>1.07</y>
#       </pt>
#       <pt>
#         <x>725.04</x>
#         <y>349.06</y>
#       </pt>
#       <pt>
#         <x>127.55</x>
#         <y>445.15</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=3, keyframe=True</attributes>
#   </object>
# </annotation>
#
# <annotation>
#   <filename>2 (134).jpg</filename>
#   <folder></folder>
#   <source>
#     <sourceImage></sourceImage>
#     <sourceAnnotation>Datumaro</sourceAnnotation>
#   </source>
#   <imagesize>
#     <nrows>480</nrows>
#     <ncols>854</ncols>
#   </imagesize>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>0</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>129.40</x>
#         <y>289.40</y>
#       </pt>
#       <pt>
#         <x>127.30</x>
#         <y>142.90</y>
#       </pt>
#       <pt>
#         <x>603.70</x>
#         <y>8.70</y>
#       </pt>
#       <pt>
#         <x>637.50</x>
#         <y>142.35</y>
#       </pt>
#       <pt>
#         <x>617.10</x>
#         <y>152.90</y>
#       </pt>
#       <pt>
#         <x>620.10</x>
#         <y>181.60</y>
#       </pt>
#       <pt>
#         <x>654.50</x>
#         <y>223.40</y>
#       </pt>
#       <pt>
#         <x>677.30</x>
#         <y>350.80</y>
#       </pt>
#       <pt>
#         <x>127.30</x>
#         <y>444.10</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=0, keyframe=False</attributes>
#   </object>
#   <object>
#     <name>joint</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>1</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>727.30</x>
#         <y>2.40</y>
#       </pt>
#       <pt>
#         <x>625.83</x>
#         <y>2.60</y>
#       </pt>
#       <pt>
#         <x>630.03</x>
#         <y>17.68</y>
#       </pt>
#       <pt>
#         <x>636.45</x>
#         <y>37.85</y>
#       </pt>
#       <pt>
#         <x>709.53</x>
#         <y>349.60</y>
#       </pt>
#       <pt>
#         <x>725.35</x>
#         <y>410.50</y>
#       </pt>
#       <pt>
#         <x>727.33</x>
#         <y>411.00</y>
#       </pt>
#       <pt>
#         <x>726.85</x>
#         <y>241.70</y>
#       </pt>
#       <pt>
#         <x>726.55</x>
#         <y>231.48</y>
#       </pt>
#       <pt>
#         <x>726.98</x>
#         <y>143.20</y>
#       </pt>
#       <pt>
#         <x>726.03</x>
#         <y>106.30</y>
#       </pt>
#       <pt>
#         <x>726.18</x>
#         <y>66.43</y>
#       </pt>
#       <pt>
#         <x>726.03</x>
#         <y>47.75</y>
#       </pt>
#       <pt>
#         <x>726.85</x>
#         <y>14.03</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=1, keyframe=False</attributes>
#   </object>
#   <object>
#     <name>break</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>2</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>637.91</x>
#         <y>145.70</y>
#       </pt>
#       <pt>
#         <x>621.18</x>
#         <y>154.47</y>
#       </pt>
#       <pt>
#         <x>622.97</x>
#         <y>183.12</y>
#       </pt>
#       <pt>
#         <x>651.18</x>
#         <y>216.27</y>
#       </pt>
#       <pt>
# ...
#         <x>516.70</x>
#         <y>376.96</y>
#       </pt>
#       <pt>
#         <x>564.80</x>
#         <y>378.45</y>
#       </pt>
#       <pt>
#         <x>573.25</x>
#         <y>388.10</y>
#       </pt>
#       <pt>
#         <x>577.30</x>
#         <y>400.20</y>
#       </pt>
#       <pt>
#         <x>583.10</x>
#         <y>416.80</y>
#       </pt>
#       <pt>
#         <x>471.50</x>
#         <y>421.70</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=5, keyframe=False</attributes>
#   </object>
# </annotation>
#
# <annotation>
#   <filename>2 (27).jpg</filename>
#   <folder></folder>
#   <source>
#     <sourceImage></sourceImage>
#     <sourceAnnotation>Datumaro</sourceAnnotation>
#   </source>
#   <imagesize>
#     <nrows>480</nrows>
#     <ncols>854</ncols>
#   </imagesize>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>0</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>219.40</x>
#         <y>283.20</y>
#       </pt>
#       <pt>
#         <x>232.50</x>
#         <y>123.80</y>
#       </pt>
#       <pt>
#         <x>610.50</x>
#         <y>2.50</y>
#       </pt>
#       <pt>
#         <x>683.60</x>
#         <y>1.60</y>
#       </pt>
#       <pt>
#         <x>725.60</x>
#         <y>2.40</y>
#       </pt>
#       <pt>
#         <x>726.70</x>
#         <y>110.00</y>
#       </pt>
#       <pt>
#         <x>722.00</x>
#         <y>190.20</y>
#       </pt>
#       <pt>
#         <x>724.40</x>
#         <y>340.30</y>
#       </pt>
#       <pt>
#         <x>177.20</x>
#         <y>430.40</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=0, keyframe=True</attributes>
#   </object>
#   <object>
#     <name>joint</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>1</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>140.80</x>
#         <y>165.80</y>
#       </pt>
#       <pt>
#         <x>131.40</x>
#         <y>6.00</y>
#       </pt>
#       <pt>
#         <x>214.70</x>
#         <y>1.70</y>
#       </pt>
#       <pt>
#         <x>222.80</x>
#         <y>61.80</y>
#       </pt>
#       <pt>
#         <x>226.80</x>
#         <y>103.20</y>
#       </pt>
#       <pt>
#         <x>226.10</x>
#         <y>156.30</y>
#       </pt>
#       <pt>
#         <x>223.30</x>
#         <y>222.70</y>
#       </pt>
#       <pt>
#         <x>203.70</x>
#         <y>324.50</y>
#       </pt>
#       <pt>
#         <x>146.40</x>
#         <y>480.00</y>
#       </pt>
#       <pt>
#         <x>129.00</x>
#         <y>479.50</y>
#       </pt>
#       <pt>
#         <x>128.70</x>
#         <y>276.80</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=1, keyframe=True</attributes>
#   </object>
# </annotation>
#
# <annotation>
#   <filename>2 (68).jpg</filename>
#   <folder></folder>
#   <source>
#     <sourceImage></sourceImage>
#     <sourceAnnotation>Datumaro</sourceAnnotation>
#   </source>
#   <imagesize>
#     <nrows>480</nrows>
#     <ncols>854</ncols>
#   </imagesize>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>0</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>128.30</x>
#         <y>143.13</y>
#       </pt>
#       <pt>
#         <x>314.91</x>
#         <y>85.04</y>
#       </pt>
#       <pt>
#         <x>321.36</x>
#         <y>161.19</y>
#       </pt>
#       <pt>
#         <x>316.20</x>
#         <y>222.64</y>
#       </pt>
#       <pt>
#         <x>295.13</x>
#         <y>228.23</y>
#       </pt>
#       <pt>
#         <x>291.69</x>
#         <y>251.45</y>
#       </pt>
#       <pt>
#         <x>308.46</x>
#         <y>277.29</y>
#       </pt>
#       <pt>
#         <x>300.72</x>
#         <y>320.72</y>
#       </pt>
#       <pt>
#         <x>289.54</x>
#         <y>373.99</y>
#       </pt>
#       <pt>
#         <x>274.92</x>
#         <y>421.72</y>
#       </pt>
#       <pt>
#         <x>126.58</x>
#         <y>452.72</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes></attributes>
#   </object>
#   <object>
#     <name>break</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>1</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>316.20</x>
#         <y>225.22</y>
#       </pt>
#       <pt>
#         <x>297.28</x>
#         <y>230.38</y>
#       </pt>
#       <pt>
#         <x>293.84</x>
#         <y>250.16</y>
#       </pt>
#       <pt>
#         <x>308.89</x>
#         <y>277.29</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes></attributes>
#   </object>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>2</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>436.60</x>
#         <y>292.70</y>
#       </pt>
#       <pt>
#         <x>431.30</x>
#         <y>53.70</y>
#       </pt>
#       <pt>
#         <x>610.50</x>
#         <y>2.50</y>
#       </pt>
#       <pt>
#         <x>683.60</x>
#         <y>1.60</y>
#       </pt>
#       <pt>
#         <x>725.60</x>
#         <y>2.40</y>
#       </pt>
#       <pt>
#         <x>726.70</x>
#         <y>110.00</y>
#       </pt>
#       <pt>
#         <x>722.00</x>
#         <y>190.20</y>
#       </pt>
#       <pt>
#         <x>724.40</x>
#         <y>340.30</y>
#       </pt>
#       <pt>
#         <x>432.60</x>
#         <y>384.90</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=0, keyframe=True</attributes>
#   </object>
#   <object>
#     <name>joint</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>3</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>305.00</x>
#         <y>368.80</y>
#       </pt>
#       <pt>
#         <x>333.60</x>
#         <y>159.90</y>
#       </pt>
#       <pt>
#         <x>318.10</x>
#         <y>39.30</y>
#       </pt>
#       <pt>
#         <x>314.80</x>
#         <y>1.30</y>
#       </pt>
#       <pt>
#         <x>342.00</x>
#         <y>0.00</y>
#       </pt>
#       <pt>
#         <x>382.00</x>
#         <y>1.00</y>
#       </pt>
#       <pt>
#         <x>411.40</x>
#         <y>0.00</y>
#       </pt>
#       <pt>
#         <x>422.50</x>
#         <y>65.40</y>
#       </pt>
#       <pt>
#         <x>432.10</x>
#         <y>263.40</y>
#       </pt>
#       <pt>
#         <x>397.10</x>
#         <y>479.10</y>
#       </pt>
#       <pt>
#         <x>268.50</x>
#         <y>480.00</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=1, keyframe=True</attributes>
#   </object>
# </annotation>
#
# <annotation>
#   <filename>1.1 (673).jpg</filename>
#   <folder></folder>
#   <source>
#     <sourceImage></sourceImage>
#     <sourceAnnotation>Datumaro</sourceAnnotation>
#   </source>
#   <imagesize>
#     <nrows>480</nrows>
#     <ncols>854</ncols>
#   </imagesize>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>0</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>267.80</x>
#         <y>132.90</y>
#       </pt>
#       <pt>
#         <x>485.40</x>
#         <y>74.40</y>
#       </pt>
#       <pt>
#         <x>585.50</x>
#         <y>44.90</y>
#       </pt>
#       <pt>
#         <x>584.40</x>
#         <y>240.80</y>
#       </pt>
#       <pt>
#         <x>269.20</x>
#         <y>286.90</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=3, keyframe=True</attributes>
#   </object>
# </annotation>
#
# <annotation>
#   <filename>3 (124).jpg</filename>
#   <folder></folder>
#   <source>
#     <sourceImage></sourceImage>
#     <sourceAnnotation>Datumaro</sourceAnnotation>
#   </source>
#   <imagesize>
#     <nrows>480</nrows>
#     <ncols>854</ncols>
#   </imagesize>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>0</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>267.44</x>
#         <y>131.58</y>
#       </pt>
#       <pt>
#         <x>585.58</x>
#         <y>34.29</y>
#       </pt>
#       <pt>
#         <x>588.16</x>
#         <y>233.18</y>
#       </pt>
#       <pt>
#         <x>269.60</x>
#         <y>284.40</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=4, keyframe=False</attributes>
#   </object>
#   <object>
#     <name>break</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>1</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>332.40</x>
#         <y>421.50</y>
#       </pt>
#       <pt>
#         <x>357.80</x>
#         <y>407.40</y>
#       </pt>
#       <pt>
#         <x>393.40</x>
#         <y>406.80</y>
#       </pt>
#       <pt>
#         <x>405.20</x>
#         <y>424.40</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=6, keyframe=False</attributes>
#   </object>
# </annotation>
#
# <annotation>
#   <filename>3 (138).jpg</filename>
#   <folder></folder>
#   <source>
#     <sourceImage></sourceImage>
#     <sourceAnnotation>Datumaro</sourceAnnotation>
#   </source>
#   <imagesize>
#     <nrows>480</nrows>
#     <ncols>854</ncols>
#   </imagesize>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>0</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>267.44</x>
#         <y>131.58</y>
#       </pt>
#       <pt>
#         <x>585.58</x>
#         <y>34.29</y>
#       </pt>
#       <pt>
#         <x>588.16</x>
#         <y>233.18</y>
#       </pt>
#       <pt>
#         <x>269.60</x>
#         <y>284.40</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=4, keyframe=False</attributes>
#   </object>
#   <object>
#     <name>break</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>1</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>376.30</x>
#         <y>420.30</y>
#       </pt>
#       <pt>
#         <x>405.10</x>
#         <y>403.70</y>
#       </pt>
#       <pt>
#         <x>454.70</x>
#         <y>405.30</y>
#       </pt>
#       <pt>
#         <x>471.30</x>
#         <y>423.60</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=6, keyframe=True</attributes>
#   </object>
# </annotation>
#
# <annotation>
#   <filename>3 (127).jpg</filename>
#   <folder></folder>
#   <source>
#     <sourceImage></sourceImage>
#     <sourceAnnotation>Datumaro</sourceAnnotation>
#   </source>
#   <imagesize>
#     <nrows>480</nrows>
#     <ncols>854</ncols>
#   </imagesize>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>0</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>267.44</x>
#         <y>131.58</y>
#       </pt>
#       <pt>
#         <x>585.58</x>
#         <y>34.29</y>
#       </pt>
#       <pt>
#         <x>588.16</x>
#         <y>233.18</y>
#       </pt>
#       <pt>
#         <x>269.60</x>
#         <y>284.40</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=4, keyframe=False</attributes>
#   </object>
#   <object>
#     <name>break</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>1</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>332.40</x>
#         <y>421.50</y>
#       </pt>
#       <pt>
#         <x>357.80</x>
#         <y>407.40</y>
#       </pt>
#       <pt>
#         <x>400.20</x>
#         <y>406.60</y>
#       </pt>
#       <pt>
#         <x>412.85</x>
#         <y>423.80</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=6, keyframe=False</attributes>
#   </object>
# </annotation>
#
# <annotation>
#   <filename>2 (114).jpg</filename>
#   <folder></folder>
#   <source>
#     <sourceImage></sourceImage>
#     <sourceAnnotation>Datumaro</sourceAnnotation>
#   </source>
#   <imagesize>
#     <nrows>480</nrows>
#     <ncols>854</ncols>
#   </imagesize>
#   <object>
#     <name>break</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>0</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>533.50</x>
#         <y>174.97</y>
#       </pt>
#       <pt>
#         <x>507.34</x>
#         <y>193.60</y>
#       </pt>
#       <pt>
#         <x>519.88</x>
#         <y>218.32</y>
#       </pt>
#       <pt>
#         <x>538.88</x>
#         <y>224.42</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes></attributes>
#   </object>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>1</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>128.21</x>
#         <y>146.72</y>
#       </pt>
#       <pt>
#         <x>516.60</x>
#         <y>37.20</y>
#       </pt>
#       <pt>
#         <x>533.30</x>
#         <y>171.50</y>
#       </pt>
#       <pt>
#         <x>503.70</x>
#         <y>193.20</y>
#       </pt>
#       <pt>
#         <x>518.40</x>
#         <y>221.30</y>
#       </pt>
#       <pt>
#         <x>537.30</x>
#         <y>227.80</y>
#       </pt>
#       <pt>
#         <x>547.20</x>
#         <y>322.00</y>
#       </pt>
#       <pt>
#         <x>555.60</x>
#         <y>382.10</y>
#       </pt>
#       <pt>
#         <x>126.72</x>
#         <y>456.60</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=0, keyframe=True</attributes>
#   </object>
#   <object>
#     <name>joint</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>2</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>513.20</x>
#         <y>1.90</y>
#       </pt>
#       <pt>
#         <x>635.20</x>
#         <y>2.90</y>
#       </pt>
#       <pt>
#         <x>658.00</x>
#         <y>105.00</y>
#       </pt>
#       <pt>
#         <x>714.40</x>
#         <y>353.70</y>
#       </pt>
#       <pt>
#         <x>728.10</x>
#         <y>479.70</y>
#       </pt>
#       <pt>
#         <x>611.80</x>
#         <y>480.00</y>
#       </pt>
#       <pt>
#         <x>564.40</x>
#         <y>479.60</y>
#       </pt>
#       <pt>
#         <x>563.80</x>
#         <y>419.70</y>
#       </pt>
#       <pt>
#         <x>551.60</x>
#         <y>311.00</y>
#       </pt>
#       <pt>
#         <x>538.60</x>
#         <y>160.30</y>
#       </pt>
#       <pt>
#         <x>522.40</x>
#         <y>54.70</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=1, keyframe=True</attributes>
#   </object>
#   <object>
#     <name>crack</name>
#     <deleted>0</deleted>
#     <verified>0</verified>
#     <occluded>no</occluded>
#     <date></date>
#     <id>3</id>
#     <parts>
#       <hasparts></hasparts>
#       <ispartof></ispartof>
#     </parts>
#     <polygon>
#       <pt>
#         <x>673.20</x>
#         <y>61.55</y>
#       </pt>
#       <pt>
#         <x>671.50</x>
#         <y>51.60</y>
#       </pt>
#       <pt>
#         <x>661.88</x>
#         <y>2.67</y>
#       </pt>
#       <pt>
#         <x>724.50</x>
#         <y>2.80</y>
#       </pt>
#       <pt>
#         <x>726.30</x>
#         <y>273.90</y>
#       </pt>
#       <pt>
#         <x>724.00</x>
#         <y>293.35</y>
#       </pt>
#       <pt>
#         <x>717.10</x>
#         <y>296.70</y>
#       </pt>
#       <pt>
#         <x>676.60</x>
#         <y>84.75</y>
#       </pt>
#       <username></username>
#     </polygon>
#     <attributes>track_id=3, keyframe=False</attributes>
#   </object>
# </annotation>

# %% [markdown]
# Функции создания датасета из загруженных данных (изображений и разметки)

# %%
# Функция для конвертации XML в DataFrame
def xml_to_csv(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()

    filename = root.find('filename').text
    width = int(root.find('imagesize').find('ncols').text)
    height = int(root.find('imagesize').find('nrows').text)

    data = []
    for obj in root.findall('object'):
        obj_name = obj.find('name').text
        xmin = ymin = xmax = ymax = None

        if len(obj.findall('polygon')) > 0:
            polygon = obj.find('polygon')
            pts = polygon.findall('pt')
            x_coords = [float(pt.find('x').text) for pt in pts]
            y_coords = [float(pt.find('y').text) for pt in pts]
            xmin = min(x_coords)
            xmax = max(x_coords)
            ymin = min(y_coords)
            ymax = max(y_coords)

        data.append([filename, width, height, obj_name, xmin, ymin, xmax, ymax])

    column_names = ['filename', 'width', 'height', 'class', 'xmin', 'ymin', 'xmax', 'ymax']
    df = pd.DataFrame(data, columns=column_names)
    return df

# %%
# Создаем пустой DataFrame для сохранения данных
labels_df = pd.DataFrame()

# %%
# Пройдем по всем XML файлам в папке с аннотациями и конвертируем их в CSV
for file in os.listdir(annotations):
    if file.endswith('.xml'):
        df = xml_to_csv(os.path.join(annotations, file))
        labels_df = pd.concat([labels_df, df], ignore_index=True)


print('Successfully converted xml to csv.')
print(labels_df)
# Out:
# Successfully converted xml to csv.
#         filename  width  height  class    xmin    ymin    xmax    ymax
# 0    2 (112).jpg    854     480  break  505.52  177.12  537.08  233.02
# 1    2 (112).jpg    854     480  crack  126.72   39.05  548.75  456.60
# 2    2 (112).jpg    854     480  joint  507.45    1.20  722.75  479.80
# 3    2 (112).jpg    854     480  crack  632.60    2.80  725.70  352.80
# 4     3 (86).jpg    854     480  crack  267.44   34.29  588.16  284.40
# ..           ...    ...     ...    ...     ...     ...     ...     ...
# 919  3 (127).jpg    854     480  break  332.40  406.60  412.85  423.80
# 920  2 (114).jpg    854     480  break  507.34  174.97  538.88  224.42
# 921  2 (114).jpg    854     480  crack  126.72   37.20  555.60  456.60
# 922  2 (114).jpg    854     480  joint  513.20    1.90  728.10  480.00
# 923  2 (114).jpg    854     480  crack  661.88    2.67  726.30  296.70
#
# [924 rows x 8 columns]

# %%
# Загрузите DataFrame с аннотациями
labels_df
# Out:
#         filename  width  height  class    xmin    ymin    xmax    ymax
# 0    2 (112).jpg    854     480  break  505.52  177.12  537.08  233.02
# 1    2 (112).jpg    854     480  crack  126.72   39.05  548.75  456.60
# 2    2 (112).jpg    854     480  joint  507.45    1.20  722.75  479.80
# 3    2 (112).jpg    854     480  crack  632.60    2.80  725.70  352.80
# 4     3 (86).jpg    854     480  crack  267.44   34.29  588.16  284.40
# ..           ...    ...     ...    ...     ...     ...     ...     ...
# 919  3 (127).jpg    854     480  break  332.40  406.60  412.85  423.80
# 920  2 (114).jpg    854     480  break  507.34  174.97  538.88  224.42
# 921  2 (114).jpg    854     480  crack  126.72   37.20  555.60  456.60
# 922  2 (114).jpg    854     480  joint  513.20    1.90  728.10  480.00
# 923  2 (114).jpg    854     480  crack  661.88    2.67  726.30  296.70
#
# [924 rows x 8 columns]

# %% [markdown]
# Уменьшаем размер изображений

# %%
# Укажите исходные и новые размеры изображений
original_width, original_height = 854, 480
new_width, new_height = 600, 337

# %%
def resize_image_and_update_coords(image_path, boxes):
    with Image.open(image_path) as img:
        img_resized = img.resize((new_width, new_height), Image.ANTIALIAS)

        # Сохраните новое изображение в нужную директорию (например, "images_resized")
        new_image_path = os.path.join("images_resized", os.path.basename(image_path))
        os.makedirs("images_resized", exist_ok=True)
        img_resized.save(new_image_path)

        # Обновите координаты bounding boxes
        scale_x = new_width / original_width
        scale_y = new_height / original_height
        boxes = boxes.copy()
        boxes['xmin'] = boxes['xmin'] * scale_x
        boxes['ymin'] = boxes['ymin'] * scale_y
        boxes['xmax'] = boxes['xmax'] * scale_x
        boxes['ymax'] = boxes['ymax'] * scale_y

        # Обновите размеры изображения в DataFrame
        boxes['width'] = new_width
        boxes['height'] = new_height
        boxes['filename'] = os.path.basename(new_image_path)

        return boxes

# %%
# Обрабатываем каждое изображение и обновляем координаты
updated_frames = []
for image_file in tqdm(labels_df['filename'].unique()):
    image_path = os.path.join("images", image_file)  # Укажите путь к директории с изображениями

    # Получаем все записи для данного изображения
    image_boxes = labels_df[labels_df['filename'] == image_file]

    # Обновляем координаты bounding boxes
    updated_boxes = resize_image_and_update_coords(image_path, image_boxes)

    updated_frames.append(updated_boxes)

# Объединяем все обновленные DataFrame
updated_labels_df = pd.concat(updated_frames)
# Out:
#   0%|          | 0/210 [00:00<?, ?it/s]<ipython-input-54-4ea363e3c06b>:3: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img_resized = img.resize((new_width, new_height), Image.ANTIALIAS)
# 100%|██████████| 210/210 [00:03<00:00, 55.38it/s]

# %%
updated_labels_df
# Out:
#         filename  width  height  class        xmin        ymin        xmax  \
# 0    2 (112).jpg    600     337  break  355.166276  124.353000  377.339578
# 1    2 (112).jpg    600     337  crack   89.030445   27.416354  385.538642
# 2    2 (112).jpg    600     337  joint  356.522248    0.842500  507.786885
# 3    2 (112).jpg    600     337  crack  444.449649    1.965833  509.859485
# 462  2 (112).jpg    600     337  break  355.166276  124.353000  377.339578
# ..           ...    ...     ...    ...         ...         ...         ...
# 461  2 (114).jpg    600     337  crack  465.021077    1.874562  510.281030
# 920  2 (114).jpg    600     337  break  356.444965  122.843521  378.604215
# 921  2 (114).jpg    600     337  crack   89.030445   26.117500  390.351288
# 922  2 (114).jpg    600     337  joint  360.562061    1.333958  511.545667
# 923  2 (114).jpg    600     337  crack  465.021077    1.874562  510.281030
#
#            ymax
# 0    163.599458
# 1    320.571250
# 2    336.859583
# 3    247.695000
# 462  163.599458
# ..          ...
# 461  208.308125
# 920  157.561542
# 921  320.571250
# 922  337.000000
# 923  208.308125
#
# [924 rows x 8 columns]

# %% [markdown]
# Кодируем целевую категориальную переменную

# %%
from sklearn.preprocessing import LabelEncoder

labelencoder = LabelEncoder()
updated_labels_df['class'] = labelencoder.fit_transform(updated_labels_df['class'])

# %%
updated_labels_df
# Out:
#         filename  width  height  class        xmin        ymin        xmax  \
# 0    2 (112).jpg    600     337      0  355.166276  124.353000  377.339578
# 1    2 (112).jpg    600     337      1   89.030445   27.416354  385.538642
# 2    2 (112).jpg    600     337      2  356.522248    0.842500  507.786885
# 3    2 (112).jpg    600     337      1  444.449649    1.965833  509.859485
# 462  2 (112).jpg    600     337      0  355.166276  124.353000  377.339578
# ..           ...    ...     ...    ...         ...         ...         ...
# 461  2 (114).jpg    600     337      1  465.021077    1.874562  510.281030
# 920  2 (114).jpg    600     337      0  356.444965  122.843521  378.604215
# 921  2 (114).jpg    600     337      1   89.030445   26.117500  390.351288
# 922  2 (114).jpg    600     337      2  360.562061    1.333958  511.545667
# 923  2 (114).jpg    600     337      1  465.021077    1.874562  510.281030
#
#            ymax
# 0    163.599458
# 1    320.571250
# 2    336.859583
# 3    247.695000
# 462  163.599458
# ..          ...
# 461  208.308125
# 920  157.561542
# 921  320.571250
# 922  337.000000
# 923  208.308125
#
# [924 rows x 8 columns]

# %% [markdown]
# Сохраняем датафрейм для дальнейшей обработки моделью

# %%
# Сохраняем обновленный DataFrame в новый CSV-файл
updated_labels_df.to_csv("new_annotations.csv", index=False)

print("Процесс завершен. Изображения и аннотации обновлены и сохранены.")
# Out:
# Процесс завершен. Изображения и аннотации обновлены и сохранены.

# %% [markdown]
# # Визуализация измененных изображений и размеченных объектов

# %%
# Укажем путь к папке с новыми изображениями
folder_path = "images_resized"

# Укажем имя создаваемого zip-архива
zip_filename = "images_resized.zip"

# Упакуем папку в zip-архив
shutil.make_archive(zip_filename.replace(".zip", ""), 'zip', folder_path)

print(f"Папка {folder_path} успешно упакована в {zip_filename}.")
# Out:
# Папка images_resized успешно упакована в images_resized.zip.

# %%
from google.colab import files

files.download(zip_filename)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import os

# %%
import random

# %%
# Количество изображений для отображения
num_images_to_show = 3  # Задайте количество изображений, которые вы хотите отобразить

# Определяем цвета для каждого класса
class_colors = {
    'break': 'red',
    'crack': 'blue',
    'joint': 'green'
}

# Извлекаем уникальные имена файлов из DataFrame
unique_filenames = labels_df['filename'].unique()

# Если количество требуемых изображений больше чем доступных, ограничиваем значение
num_images_to_show = min(num_images_to_show, len(unique_filenames))

# Выбираем случайные имена файлов для визуализации
files_to_visualize = random.sample(list(unique_filenames), num_images_to_show)

# Отображаем каждое изображение с аннотациями
for filename_to_visualize in files_to_visualize:
    # Извлекаем строки DataFrame, соответствующие заданному файлу
    group_df = labels_df[labels_df['filename'] == filename_to_visualize]
    if group_df.empty:
        print(f"No annotations found for file '{filename_to_visualize}'")
        continue

    # Путь к изображению
    img_file = os.path.join(img_dir, filename_to_visualize)
    if not os.path.exists(img_file):
        print(f"Image file '{img_file}' does not exist")
        continue

    # Загрузка изображения
    image = Image.open(img_file)
    plt.figure(figsize=(8, 8))
    plt.imshow(image)

    # Отображение bounding boxes с учетом цвета для каждого класса
    for _, row in group_df.iterrows():
        xmin, ymin, xmax, ymax = row['xmin'], row['ymin'], row['xmax'], row['ymax']
        class_label = row['class']
        color = class_colors.get(class_label, 'white')  # Если класса нет в словаре, используем белый цвет

        # Прямоугольник
        plt.plot([xmin, xmax, xmax, xmin, xmin], [ymin, ymin, ymax, ymax, ymin], color=color, label=class_label)

    # Удаление дублирующихся легенд
    handles, labels = plt.gca().get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    plt.legend(by_label.values(), by_label.keys())

    plt.axis('off')
    plt.title(filename_to_visualize)
    plt.show()

# %% [markdown]
# Датафрейм содержащий информацию о разметке объектов на изображениях создан и сохранен для дальнейшей работы.
